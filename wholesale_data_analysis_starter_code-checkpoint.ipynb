# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd

df = pd.read_csv('Resources/client_dataset.csv')
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# View the column names in the data
print(df.columns.values)
# Out:
# ['first' 'last' 'job' 'phone' 'email' 'client_id' 'order_id' 'order_date'
#  'order_week' 'order_year' 'item_id' 'category' 'subcategory' 'unit_price'
#  'unit_cost' 'unit_weight' 'qty' 'line_number']

# %%
# Use the describe function to gather some basic statistics
df.describe()
# Out:
#           client_id      order_id    order_week    order_year    unit_price  \
# count  54639.000000  5.463900e+04  54639.000000  54639.000000  54639.000000
# mean   54837.869416  5.470190e+06     11.359139   2022.993064    136.267207
# std    25487.438231  2.599807e+06      7.023499      0.082997    183.873135
# min    10033.000000  1.000886e+06      1.000000   2022.000000      0.010000
# 25%    33593.000000  3.196372e+06      6.000000   2023.000000     20.800000
# 50%    53305.000000  5.496966e+06     11.000000   2023.000000     68.310000
# 75%    78498.000000  7.733869e+06     17.000000   2023.000000    173.160000
# max    99984.000000  9.998480e+06     52.000000   2023.000000   1396.230000
#
#           unit_cost   unit_weight           qty   line_number
# count  54639.000000  54639.000000  5.463900e+04  54639.000000
# mean      99.446073      5.004116  5.702646e+02      2.979667
# std      133.164267      5.326599  1.879552e+04      2.436320
# ...

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54639 entries, 0 to 54638
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   first        54639 non-null  object
#  1   last         54639 non-null  object
#  2   job          54639 non-null  object
#  3   phone        54639 non-null  object
#  4   email        54639 non-null  object
#  5   client_id    54639 non-null  int64
#  6   order_id     54639 non-null  int64
#  7   order_date   54639 non-null  object
#  8   order_week   54639 non-null  int64
#  9   order_year   54639 non-null  int64
#  10  item_id      54639 non-null  object
#  11  category     54639 non-null  object
#  12  subcategory  54639 non-null  object
#  13  unit_price   54639 non-null  float64
#  14  unit_cost    54639 non-null  float64
#  15  unit_weight  54639 non-null  float64
#  16  qty          54639 non-null  int64
#  17  line_number  54639 non-null  int64
# ...

# %%
# What three item categories had the most entries?
df['category'].value_counts().head(3)
# Out:
# category
# consumables    23538
# furniture      11915
# software        8400
# Name: count, dtype: int64

# %%
# For the category with the most entries, which subcategory had the most entries?
df['subcategory'].value_counts().head(1)
# Out:
# subcategory
# bathroom supplies    6424
# Name: count, dtype: int64

# %%
# Which five clients had the most entries in the data?
df['client_id'].value_counts().head(5)
# Out:
# client_id
# 33615    220
# 66037    211
# 46820    209
# 38378    207
# 24741    207
# Name: count, dtype: int64

# %%
# Store the client ids of those top 5 clients in a list.
clients_list = df["client_id"].value_counts().head(5).index.tolist()
clients_list
# Out:
# [33615, 66037, 46820, 38378, 24741]

# %%
# How many total units (the qty column) did the client with the most entries order order?
clients_list = df["client_id"].value_counts().head(1).index
query_str = "client_id == " + str(clients_list[0])
df.query(query_str)['qty'].sum()
# Out:
# 64313

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the subtotal for each line using the unit_price and the qty
def column_calc(row):
    return row['unit_price'] * row['qty']

df['line_subtotal'] = df.apply(lambda row: column_calc(row), axis=1)
print(df[['unit_price', 'qty', 'line_subtotal']].head(2))
# Out:
#    unit_price  qty  line_subtotal
# 0     1096.80  105      115164.00
# 1       24.95   21         523.95

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound for orders over 50 pounds and $10 per pound for items 50 pounds or under.  
def ship_price(row):
    total_weight = row['unit_weight'] * row['qty']
    if total_weight > 50:
        shipping_price = total_weight * 7
    else:
        shipping_price = total_weight * 10
    return shipping_price
    
df['shipping_price'] = df.apply(lambda row: ship_price(row), axis=1)
print(df[['unit_price', 'unit_weight', 'qty', 'shipping_price']].head(3))
# Out:
#    unit_price  unit_weight  qty  shipping_price
# 0     1096.80         7.50  105         5512.50
# 1       24.95         1.49   21          312.90
# 2       13.52         1.68   39          458.64

# %%
# Create a column for the total price using the subtotal and the shipping price along with a sales tax of 9.25%
def total_price(row):
    line_price = row['line_subtotal'] + row['shipping_price'] + ((row['line_subtotal'] + row['shipping_price']) * .0925)
    return round(line_price,2)
df['line_price'] = df.apply(lambda row: total_price(row), axis=1)
print(df[['line_subtotal', 'shipping_price', 'line_price']].head(3))
# Out:
#    line_subtotal  shipping_price  line_price
# 0      115164.00         5512.50   131839.08
# 1         523.95          312.90      914.26
# 2         527.28          458.64     1077.12

# %%
# Create a column for the cost of each line using unit cost, qty, and
# shipping price (assume the shipping cost is exactly what is charged to the client).
def column_line_cost(row):
    line_cost = (row['unit_cost'] + row['qty']) + row['shipping_price']
    return round(cost,2)
df['line_cost'] = df.apply(lambda row: line_cost(row), axis=1)
df[['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id', 'order_date','order_week', 'order_year', 'item_id', 'category', 'subcategory', 'unit_price', 'unit_cost','unit_weight', 'qty', 'line_number', 'line_subtotal', 'shipping_price', 'line_price', 'line_cost']].head(3)
# Out:
#      first     last              job               phone  \
# 0   Donald  Harding     Immunologist  793-904-7725x39308
# 1  Tiffany    Myers  Music therapist    201.442.4543x942
# 2  Shannon   Watson     Immunologist   687.737.9424x8503
#
#                                email  client_id  order_id  order_date  \
# 0   harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1  myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2              swatson8146@payne.net      57113   1902144  2023-01-29
#
#    order_week  order_year  ...         subcategory unit_price unit_cost  \
# 0          17        2023  ...            wall art    1096.80    762.71
# 1          20        2023  ...                pens      24.95     15.09
# 2           4        2023  ...  project management      13.52      7.86
#
#    unit_weight  qty  line_number  line_subtotal  shipping_price  line_price  \
# 0         7.50  105            1      115164.00         5512.50   131839.08
# ...

# %%
# Create a column for the profit of each line using line cost and line price
# profit = price - cost
def column_profit(row):
    profit = (row['line_price'] - row['line_cost'])
    return profit

df['line_profit'] = df.apply(lambda row: column_profit(row), axis=1)
df[['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id', 'order_date','order_week', 'order_year', 'item_id', 'category', 'subcategory', 'unit_price', 'unit_cost','unit_weight', 'qty', 'line_number', 'line_subtotal', 'shipping_price', 'line_price', 'line_cost' ]].head(3)
# Out:
#      first     last              job               phone  \
# 0   Donald  Harding     Immunologist  793-904-7725x39308
# 1  Tiffany    Myers  Music therapist    201.442.4543x942
# 2  Shannon   Watson     Immunologist   687.737.9424x8503
#
#                                email  client_id  order_id  order_date  \
# 0   harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1  myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2              swatson8146@payne.net      57113   1902144  2023-01-29
#
#    order_week  order_year  ...         subcategory unit_price unit_cost  \
# 0          17        2023  ...            wall art    1096.80    762.71
# 1          20        2023  ...                pens      24.95     15.09
# 2           4        2023  ...  project management      13.52      7.86
#
#    unit_weight  qty  line_number  line_subtotal  shipping_price  line_price  \
# 0         7.50  105            1      115164.00         5512.50   131839.08
# ...

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
# Check your work using the totals above
order_2742071 = round(df.loc[df['order_id'] == 2742071, 'line_price'].sum(),2)
print("Order 2742071 total: $"+f"{order_2742071:}")

order_2173913 = round(df.loc[df['order_id'] == 2173913, 'line_price'].sum(),2)
print("Order 2173913 total: $"+f"{order_2173913:}")

order_6128929 = round(df.loc[df['order_id'] == 6128929, 'line_price'].sum(),2)
print("Order 6128929 total: $"+f"{order_6128929:}")
# Out:
# Order 2742071 total: $152811.89
# Order 2173913 total: $162388.71
# Order 6128929 total: $923441.25

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
# How much did each of the top 5 clients by quantity spend? Check your work from Part 1 for client ids.
for clients_list in df["client_id"].value_counts().head(5).index.tolist():
    print(clients_list, ': $',f"{round(df.loc[df['client_id'] == clients_list, 'line_price'].sum(),2):,}")
# Out:
# 33615 : $ 8,377,308.52
# 66037 : $ 10,259,514.8
# 46820 : $ 9,743,794.33
# 38378 : $ 12,906,550.87
# 24741 : $ 82,268,892.04

# %%
# Create a summary DataFrame showing the totals for the for the top 5 clients with the following information:
# total units purchased, total shipping price, total revenue, and total profit. 
input = {'client_id': ['0'],
         'qty': ['0'],
         'shipping_price': ['0'],
         'line_price': ['0'],
         'line_cost': ['0'],
         'line_profit': ['0']
        }
row = {'client_id': 0 ,
         'qty': 0,
         'shipping_price': 0,
         'line_price': 0,
         'line_cost': 0,
         'line_profit': 0
        }

summary = pd.DataFrame(input)
top_clients_list = df["client_id"].value_counts().head(5).index.tolist()

for clients_list in df["client_id"].value_counts().head(5).index.tolist():
   row['client_id'] = clients_list
row['qty'] = f"{round(df.loc[df['client_id'] == clients_list, 'qty'].sum(),2):,}"
row['shipping_price'] = f"{round(df.loc[df['client_id'] == clients_list, 'shipping_price'].sum(),2):,}"
row['line_price'] = f"{round(df.loc[df['client_id'] == clients_list, 'line_price'].sum(),2):,}"
row['line_cost'] = f"{round(df.loc[df['client_id'] == clients_list, 'line_cost'].sum(),2):,}"
row['line_profit'] = f"{round(df.loc[df['client_id'] == clients_list, 'line_profit'].sum(),2):,}"
summary.loc[-1] = row
summary.index = summary.index +1
summary = summary.sort_index()
summary = summary.head()
summary = summary.sort_values(by='line_profit', ascending=False)
summary[['client_id', 'qty', 'shipping_price', 'line_price', 'line_cost', 'line_profit']]
# Out:
#   client_id      qty shipping_price     line_price     line_cost  \
# 0     24741  239,862   5,126,448.37  82,268,892.04  5,384,210.41
# 1         0        0              0              0             0
#
#      line_profit
# 0  76,884,681.63
# 1              0

# %%
# Format the data and rename the columns to names suitable for presentation.

input = {'Client ID': ['0'],
         'Units': ['0'],
         'Shipping (millions)': ['0'],
         'Total Revnue (millions)': ['0'],
         'Total Cost(millions)': ['0'],
         'Total Profit (millions)': ['0']
        }
row = {'Client ID': 0 ,
         'Units': 0,
         'Shipping': 0,
         'Total Revenue': 0,
         'Total Cost': 0,
         'Total Profit': 0
        }

summary = pd.DataFrame(input)
top_clients_list = df["client_id"].value_counts().head(5).index.tolist()

for clients_list in df["client_id"].value_counts().head(5).index.tolist():
   row['Client ID'] = clients_list
row['Units'] = f"{round(df.loc[df['client_id'] == clients_list, 'qty'].sum(),2):,}"
row['Shipping'] = f"${round(df.loc[df['client_id'] == clients_list, 'shipping_price'].sum(),2):,}M"
row['Total Revenue'] = f"${round(df.loc[df['client_id'] == clients_list, 'line_price'].sum(),2):,}M"
row['Total Cost'] = f"${round(df.loc[df['client_id'] == clients_list, 'line_cost'].sum(),2):,}M"
row['Total Profit'] = f"${round(df.loc[df['client_id'] == clients_list, 'line_profit'].sum(),2):,}M"
summary.loc[-1] = row
summary.index = summary.index +1
summary = summary.sort_index()
summary = summary.head()
summary = summary.sort_values(by='Total Profit', ascending=False)
summary[['Client ID', 'Units', 'Shipping', 'Total Revenue', 'Total Cost', 'Total Profit']]
                                     

# Define the money columns. 


# Define a function that converts a dollar amount to millions.


# Apply the currency_format_millions function to only the money columns. 


# Rename the columns to reflect the change in the money format.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10404\1501601580.py in ?()
#      28 summary.loc[-1] = row
#      29 summary.index = summary.index +1
#      30 summary = summary.sort_index()
#      31 summary = summary.head()
# ---> 32 summary = summary.sort_values(by='Total Profit', ascending=False)
#      33 summary[['Client ID', 'Units', 'Shipping', 'Total Revenue', 'Total Cost', 'Total Profit']]
#      34
#      35
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6940             )
#    6941         elif len(by):
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
# ...

# %%
# Sort the updated data by "Total Profit (millions)" form highest to lowest and assign the sort to a new DatFrame.
# Out:
#    Client ID   Units  Shipping (millions)  Total Revenue (millions)  \
# 4      24741  239862             5.126448                 82.268892
# 3      38378   73667             3.429455                 12.906551
# 1      66037   43018             1.395152                 10.259515
# 2      46820   75768             1.601449                  9.743794
# 0      33615   64313             1.828985                  8.377309
#
#    Total Cost (millions)  Total Profit (millions)
# 4              45.688900                36.579992
# 3               9.634721                 3.271830
# 1               7.004483                 3.255032
# 2               7.007192                 2.736603
# 0               6.175314                 2.201995
